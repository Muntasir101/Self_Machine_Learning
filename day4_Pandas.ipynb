# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in c:\users\asus\appdata\roaming\python\python312\site-packages (2.2.0)
# Requirement already satisfied: numpy<2,>=1.26.0 in c:\users\asus\appdata\roaming\python\python312\site-packages (from pandas) (1.26.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\asus\appdata\roaming\python\python312\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\asus\appdata\roaming\python\python312\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\asus\appdata\roaming\python\python312\site-packages (from pandas) (2023.4)
# Requirement already satisfied: six>=1.5 in c:\users\asus\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
s = pd.Series([10,20,30,40,50], name = "Marks")

# %%
s
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# Name: Marks, dtype: int64

# %%
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# Name: Marks, dtype: int64

# %%
print(s.values)
# Out:
# [10 20 30 40 50]

# %%
print(s.index)
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
data = {
    'Name':['Alice','Bob','charlie'],
    'Age': [25,30,40],
    'Salary': [50000,70000,80000]
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#       Name  Age  Salary
# 0    Alice   25   50000
# 1      Bob   30   70000
# 2  charlie   40   80000

# %%
print(df.shape)
# Out:
# (3, 3)

# %%
print(df.columns)
# Out:
# Index(['Name', 'Age', 'Salary'], dtype='object')

# %%
print(df.index)
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df['Name']
# Out:
# 0      Alice
# 1        Bob
# 2    charlie
# Name: Name, dtype: object

# %%
df[['Name','Age']]
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  charlie   40

# %%
df.iloc[0]  # row selection with index
# Out:
# Name        Bob
# Age          30
# Salary    70000
# Name: 1, dtype: object

# %%
df.iloc[1:3]
# Out:
#       Name  Age  Salary
# 1      Bob   30   70000
# 2  charlie   40   80000

# %%
print(df[df['Age'] > 30])
# Out:
#       Name  Age  Salary
# 2  charlie   40   80000

# %%
# Data Cleaning

# %%
import numpy as np

# %%
data = {
    'Name':['Alice','Bob','charlie','David'],
    'Age': [25,np.nan,30,40],
    'Salary': [50000,70000,np.nan, 80000]
}

# %%
df = pd.DataFrame(data)

# %%
print(df.isnull()) # detect missing data
# Out:
#     Name    Age  Salary
# 0  False  False   False
# 1  False   True   False
# 2  False  False    True
# 3  False  False   False

# %%
df.isnull().sum() # count missing per column
# Out:
# Name      0
# Age       1
# Salary    1
# dtype: int64

# %%
df
# Out:
#       Name   Age   Salary
# 0    Alice  25.0  50000.0
# 1      Bob   NaN  70000.0
# 2  charlie  30.0      NaN
# 3    David  40.0  80000.0

# %%
df['Age'] = df['Age'].fillna(df['Age'].mean())

# %%
print(df)
# Out:
#       Name        Age   Salary
# 0    Alice  25.000000  50000.0
# 1      Bob  31.666667  70000.0
# 2  charlie  30.000000      NaN
# 3    David  40.000000  80000.0

# %%
df['Salary'] = df['Salary'].fillna(0)

# %%
df
# Out:
#       Name        Age   Salary
# 0    Alice  25.000000  50000.0
# 1      Bob  31.666667  70000.0
# 2  charlie  30.000000      0.0
# 3    David  40.000000  80000.0

# %%
data = {
    'Name':['Alice','Bob','charlie','Alice'],
    'Age': [25,np.nan,30,40],
    'Salary': [50000,50000,np.nan, 50000],
    'Salary2': [10000,50000,np.nan, 50000]
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#       Name   Age   Salary  Salary2
# 0    Alice  25.0  50000.0  10000.0
# 1      Bob   NaN  50000.0  50000.0
# 2  charlie  30.0      NaN      NaN
# 3    Alice  40.0  50000.0  50000.0

# %%
df.dropna() # drop rown when missing values
# Out:
#     Name   Age   Salary
# 0  Alice  25.0  50000.0
# 3  David  40.0  50000.0

# %%
df = pd.DataFrame({
    'Name':['Alice','Bob','Alice'],
    'Age': [25,     50,     25]
})

# %%
print(df.duplicated())  # cheeck duplicate
# Out:
# 0    False
# 1    False
# 2     True
# dtype: bool

# %%
df.drop_duplicates()  # remove duplicates
# Out:
#     Name  Age
# 0  Alice   25
# 1    Bob   50

# %%
df.rename(columns={'Age':'Secret'}, inplace = True)

# %%
df
# Out:
#     Name  Secret
# 0  Alice      25
# 1    Bob      50
# 2  Alice      25

# %%
df =pd.DataFrame ({
    'Name':['Alice','Bob','charlie','David'],
    'Age': [25,30,30,40],
    'Salary': [50000,60000,70000, 80000]
})

# %%
df['Bonus'] = df['Salary'] * 0.1

# %%
df
# Out:
#       Name  Age  Salary   Bonus
# 0    Alice   25   50000  5000.0
# 1      Bob   30   60000  6000.0
# 2  charlie   30   70000  7000.0
# 3    David   40   80000  8000.0

# %%
df['Total'] = df['Salary'] + df['Bonus']

# %%
df
# Out:
#       Name  Age  Salary   Bonus    Total
# 0    Alice   25   50000  5000.0  55000.0
# 1      Bob   30   60000  6000.0  66000.0
# 2  charlie   30   70000  7000.0  77000.0
# 3    David   40   80000  8000.0  88000.0

# %%
# Grouping and Aggregation

# %%
df =pd.DataFrame ({
    'Department':['HR','IT','HR','IT','Finance','Marketing'],
    'Age': [25,30,30,40,20,21],
    'Salary': [50000,60000,70000, 80000, 30000, 20000]
})

# %%
df.groupby('Department')['Salary'].mean()
# Out:
# Department
# Finance      30000.0
# HR           60000.0
# IT           70000.0
# Marketing    20000.0
# Name: Salary, dtype: float64

# %%
# Feature Engineering

# %%
df['Salary_in_Lakhs'] = df['Salary']/100000

# %%
df
# Out:
#   Department  Age  Salary  Salary_in_Lakhs
# 0         HR   25   50000              0.5
# 1         IT   30   60000              0.6
# 2         HR   30   70000              0.7
# 3         IT   40   80000              0.8
# 4    Finance   20   30000              0.3
# 5  Marketing   21   20000              0.2

# %%
df['Age_Category'] = df['Age'].apply(lambda x: 'Junior' if x < 30 else 'Senior')

# %%
df
# Out:
#   Department  Age  Salary  Salary_in_Lakhs Age_Category
# 0         HR   25   50000              0.5       Junior
# 1         IT   30   60000              0.6       Senior
# 2         HR   30   70000              0.7       Senior
# 3         IT   40   80000              0.8       Senior
# 4    Finance   20   30000              0.3       Junior
# 5  Marketing   21   20000              0.2       Junior

# %%
df1 = pd.DataFrame({
    'ID' : [1,2],
    'Name' : ['Alice', 'Bob'],
    'Salary': [50000,60000]
})

# %%
df2 = pd.DataFrame({
    'ID' : [3, 4, 5],
    'Name' : ['Charlie', 'david', 'John']
})

# %%
result = pd.concat([df1, df2])

# %%
result
# Out:
#    ID     Name   Salary
# 0   1    Alice  50000.0
# 1   2      Bob  60000.0
# 0   3  Charlie      NaN
# 1   4    david      NaN
# 2   5     John      NaN

# %%
pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: seaborn in c:\users\asus\appdata\roaming\python\python312\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\asus\appdata\roaming\python\python312\site-packages (from seaborn) (1.26.3)
# Requirement already satisfied: pandas>=1.2 in c:\users\asus\appdata\roaming\python\python312\site-packages (from seaborn) (2.2.0)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\asus\appdata\roaming\python\python312\site-packages (from seaborn) (3.10.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\asus\appdata\roaming\python\python312\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\asus\appdata\roaming\python\python312\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\asus\appdata\roaming\python\python312\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\asus\appdata\roaming\python\python312\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\asus\appdata\roaming\python\python312\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\asus\appdata\roaming\python\python312\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\asus\appdata\roaming\python\python312\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\asus\appdata\roaming\python\python312\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\asus\appdata\roaming\python\python312\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\asus\appdata\roaming\python\python312\site-packages (from pandas>=1.2->seaborn) (2023.4)
# Requirement already satisfied: six>=1.5 in c:\users\asus\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sn

# %%
titanic = sn.load_dataset("titanic")

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
titanic.shape
# Out:
# (891, 15)

# %%
titanic.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
titanic['survived'].value_counts()
# Out:
# survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
# correlation

# %%
titanic[['age','survived']].corr()
# Out:
#                age  survived
# age       1.000000 -0.077221
# survived -0.077221  1.000000
