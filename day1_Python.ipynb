# %%
stack = []

# %%
stack.append(10)

# %%
print(stack)
# Out:
# [10]

# %%
stack.append(20)

# %%
stack.append(5)

# %%
top_item = stack.pop()

# %%
print(stack)
# Out:
# [10, 20]

# %%
print(top_item)
# Out:
# 5

# %%
print(stack[-1])
# Out:
# 20

# %%
from collections import deque

# %%
queue = deque()

# %%
queue.append("alice")

# %%
queue.append("bob")

# %%
queue.append("charls")

# %%
queue.append("cat")

# %%
queue.append("dog")

# %%
print(queue)
# Out:
# deque(['alice', 'bob', 'charls', 'cat', 'dog'])

# %%
first = queue.popleft()

# %%
print(queue)
# Out:
# deque(['bob', 'charls', 'cat', 'dog'])

# %%
second = queue.popleft()

# %%
print(queue)
# Out:
# deque(['charls', 'cat', 'dog'])
